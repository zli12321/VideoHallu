# %%
import pandas as pd
import json

with open('./synthetic_data.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
import os

for ele in data:
    if not os.path.exists(ele['path']):
        print('Nah')
        print(ele)
        break

# %%
with open('./synthetic_data.json', 'r', encoding='utf-8') as f:
    data1 = json.load(f)

with open('./Video-R1-Videos.json', 'r', encoding='utf-8') as f:
    data2 = json.load(f)

# %%
all_data = data1 + data2

# %%
len(all_data)
# Out:
# 5300

# %%
with open("./mixed_data.json", "w", encoding="utf-8") as f:
    json.dump(all_data, f, indent=2, ensure_ascii=False)
