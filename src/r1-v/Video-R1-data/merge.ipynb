# %%
import json

with open('./physbench_full_sft_data.json', 'r', encoding='utf-8') as f:
    data1 = json.load(f)

with open('./synthetic_data_sft_full_train.json', 'r', encoding='utf-8') as f:
    data2 = json.load(f)

# %%
physics_synthetic = data1 + data2

# %%
len(physics_synthetic)
# Out:
# 24572

# %%
with open("./physics_synthetic_full_sft.json", "w", encoding="utf-8") as f:
    json.dump(physics_synthetic, f, indent=2, ensure_ascii=False)
